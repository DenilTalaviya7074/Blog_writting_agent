# %%
from langchain_tavily import TavilySearch
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
tool = TavilySearch(max_results=2)
results = tool.invoke({"query": 'top global news today'})
results
# Out:
# {'query': 'top global news today',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://apnews.com/world-news',
#    'title': 'Top & Breaking World News Today',
# ...

# %%
for r in results['results']:
    print(r['content'])
# Out:
# The Associated Press is an independent global news organization dedicated to factual reporting. Founded in 1846, AP today remains the most trusted source of fast, accurate, unbiased news in all formats and the essential provider of the technology and services vital to the news business. More than half the world’s population sees AP journalism every day.
#
#
# ### Iran and Oman move closer to a deal on the Strait of Hormuz [...] In this photo provided by the Ukrainian Emergency Service, a firefighter puts out a fire following a Russian missile attack in Dnipropetrovsk region, Ukraine, Tuesday, Aug. 4, 2026. (Ukrainian Emergency Service via AP)
#
# ### Russia and Ukraine trade drone attacks with 5 killed in each country
#
# [deltaMinutes] mins ago Now
#
# ## GLOBAL BUSINESS NEWS [...] TOP STORIES
#
#   - Empty pews and fear of ICE on Maryland’s Eastern Shore after TPS ends for Haitians
# ...
