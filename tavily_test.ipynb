# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_9992\1690773881.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults
# True

# %%
tool = TavilySearchResults(max_results=2)
results = tool.invoke({"query": 'ChatGPT version releases and updates from 2022 to 2026'})
results
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_9992\1187185310.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=2)
# [{'title': 'ChatGPT — Release Notes',
#   'url': 'https://help.openai.com/en/articles/6825453-chatgpt-release-notes',
#   'content': 'Web\n   Android\n   iOS\n   Web, iOS, and Android\n   February 12, 2026\n   ChatGPT Voice Update\n   February 10, 2026\n   Updates to deep research\n   GPT-5.2 Instant Update\n   February 9, 2026\n   Testing ads in ChatGPT (Free, Go)\n   February 4, 2026\n   Update on thinking time settings for GPT-5.2 Thinking in ChatGPT\n   February 2, 2026\n   Introducing the Codex app\n   January 30, 2026\n   More visual responses\n   January 29, 2026\n   Retiring GPT-4o and other legacy models\n   January 26, 2026\n   Improvements to search response quality in Voice\n   January 22, 2026\n   5.2 Personality System Prompt Update\n   January 20, 2026\n   Voice Updates\n   Rolling out age prediction\n   January 15, 2026\n   Improved memory for finding details from past chats (Plus & Pro)\n   January 12, 2026\n   Dictation Updates [...] Retiring GPT-5.1 models\n   March 10, 2026\n   Interactive learning for math and science\n   Auto top-up for flexible usage credits\n   March 5, 2026\n   GPT-5.4 Thinking in ChatGPT\n   March 4, 2026\n   Codex app on Windows\n   March 3, 2026\n   GPT-5.3 Instant Update\n   February 27, 2026\n   ChatGPT Web and Android updates: Edit image prompts, share faster, and smoother conversations\n   Web\n   Android\n   Bug fixes\n   February 25, 2026\n   Add sources to your projects from anywhere\n   February 20, 2026\n   Expanded context window for Thinking\n   February 19, 2026\n   Interactive Code Blocks in ChatGPT\n   February 13, 2026\n   Retiring GPT-4o and other legacy models\n   ChatGPT updates: Better file uploads, easier copying, and more reliable long chats\n   Web\n   Android\n   iOS\n   Web, iOS, and Android [...] ChatGPT in Apple CarPlay\n   March 27, 2026\n   Updated Box, Notion, Linear, and Dropbox apps\n   March 26, 2026\n   A simplified sidebar on mobile\n   Location Sharing\n   Plugins in Codex\n   March 25, 2026\n   Large pastes are now handled as attachments\n   Google Drive app unification\n   March 24, 2026\n   Shopping updates in ChatGPT\n   March 23, 2026\n   File Library in ChatGPT\n   March 20, 2026\n   Codex for Students\n   March 19, 2026\n   Legacy deep research mode deprecation notice\n   March 18, 2026\n   GPT-5.4 mini in ChatGPT\n   March 17, 2026\n   Updates to the model picker in ChatGPT\n   Configure more advanced settings\n   Sunsetting the “Nerdy” base style\n   March 16, 2026\n   GPT-5.3 Instant update\n   March 11, 2026\n   Retiring GPT-5.1 models\n   March 10, 2026',
#   'score': 0.9489978},
#  {'title': 'ChatGPT Version History List, Changelog & Latest Releases',
#   'url': 'https://wpexperts.io/blog/chatgpt-version-history',
#   'content': 'Performance Update\n\nDecember 2022\n\nChatGPT launched a massive update that helped user experience, usability, and response time.\n\nChatGPT Launch\n\nNovember 2022\n\nChatGPT started its journey and introduced key advancements in NLP (Natural Language Processing).\n\nThe above ChatGPT version list indicates that previous versions of ChatGPT and ChatGPT’s latest releases are equally important when understanding the effectiveness and contributions of AI to web development, digital marketing, web design, and other domains.\n\n## What’s New in GPT-5.5?\n\nAs you may know, GPT-5.5 was officially launched on April 23, 2026. The latest model introduces major advancements in reasoning, agentic coding, deep research, and autonomous computer use. Here are some of its standout features: [...] ChatGPT Versions\n\nRelease Date\n\nSalient Features\n\nChatGPT 5.6\n\nJune 2026\n\nGPT-5.6 prioritizes dvanced reasoning, robust cybersecurity, and long-horizon agentic workflows. It has three tiers: Sol (flagship), Terra (balanced), and Luna (fastest).\n\nChatGPT 5.4\n\nMarch 2026\n\nIt focuses on reasoning, agentic workflows, and coding. It supports deep web search and helps maintain context better for queries that need longer thinking. \n\nChatGPT 5.3\n\nGPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was launched in March 2026.\n\nIt improves collaboration and supports full-cycle software development. It offers more accurate answers. \n\nChatGPT 5.2\n\nDecember 2025\n\nGPT-5.2 supports routine tasks and learning. Users were allowed to ask technical queries in a more conversational tone. [...] | Scheduled Tasks in ChatGPT | January 2025 | Schedule Tasks were automated. Users could easily set up notifications, daily reports, and AI-generated messages. |\n| OpenAI o3 Preview | December 2024 | This model announced improvements in self-correction, reliability, and problem-solving. |\n| Full o1 Model Launch | December 2024 | This model was more impactful than the previous o1-preview model. Users experienced features like function calling, image analysis, and the “Reasoning Effort” parameter. |\n| Sora Launch | December 2024 | This update or release launched the “Text-to-Video Generation” feature. It helped create top-notch 20-second videos in 1080p resolution. |',
#   'score': 0.9436445}]

# %%
for r in results:
    print(r['content'])
# Out:
# Web
#    Android
#    iOS
#    Web, iOS, and Android
#    February 12, 2026
#    ChatGPT Voice Update
#    February 10, 2026
#    Updates to deep research
#    GPT-5.2 Instant Update
#    February 9, 2026
#    Testing ads in ChatGPT (Free, Go)
#    February 4, 2026
#    Update on thinking time settings for GPT-5.2 Thinking in ChatGPT
#    February 2, 2026
#    Introducing the Codex app
#    January 30, 2026
#    More visual responses
#    January 29, 2026
#    Retiring GPT-4o and other legacy models
#    January 26, 2026
#    Improvements to search response quality in Voice
#    January 22, 2026
#    5.2 Personality System Prompt Update
#    January 20, 2026
#    Voice Updates
#    Rolling out age prediction
#    January 15, 2026
#    Improved memory for finding details from past chats (Plus & Pro)
#    January 12, 2026
#    Dictation Updates [...] Retiring GPT-5.1 models
#    March 10, 2026
#    Interactive learning for math and science
#    Auto top-up for flexible usage credits
#    March 5, 2026
#    GPT-5.4 Thinking in ChatGPT
#    March 4, 2026
#    Codex app on Windows
#    March 3, 2026
#    GPT-5.3 Instant Update
#    February 27, 2026
#    ChatGPT Web and Android updates: Edit image prompts, share faster, and smoother conversations
#    Web
#    Android
#    Bug fixes
#    February 25, 2026
#    Add sources to your projects from anywhere
#    February 20, 2026
#    Expanded context window for Thinking
#    February 19, 2026
#    Interactive Code Blocks in ChatGPT
#    February 13, 2026
#    Retiring GPT-4o and other legacy models
#    ChatGPT updates: Better file uploads, easier copying, and more reliable long chats
#    Web
#    Android
#    iOS
#    Web, iOS, and Android [...] ChatGPT in Apple CarPlay
#    March 27, 2026
#    Updated Box, Notion, Linear, and Dropbox apps
#    March 26, 2026
#    A simplified sidebar on mobile
#    Location Sharing
#    Plugins in Codex
#    March 25, 2026
#    Large pastes are now handled as attachments
#    Google Drive app unification
#    March 24, 2026
#    Shopping updates in ChatGPT
#    March 23, 2026
#    File Library in ChatGPT
#    March 20, 2026
#    Codex for Students
#    March 19, 2026
#    Legacy deep research mode deprecation notice
#    March 18, 2026
#    GPT-5.4 mini in ChatGPT
#    March 17, 2026
#    Updates to the model picker in ChatGPT
#    Configure more advanced settings
#    Sunsetting the “Nerdy” base style
#    March 16, 2026
#    GPT-5.3 Instant update
#    March 11, 2026
#    Retiring GPT-5.1 models
#    March 10, 2026
# Performance Update
#
# December 2022
#
# ChatGPT launched a massive update that helped user experience, usability, and response time.
#
# ChatGPT Launch
#
# November 2022
#
# ChatGPT started its journey and introduced key advancements in NLP (Natural Language Processing).
#
# The above ChatGPT version list indicates that previous versions of ChatGPT and ChatGPT’s latest releases are equally important when understanding the effectiveness and contributions of AI to web development, digital marketing, web design, and other domains.
#
# ## What’s New in GPT-5.5?
#
# As you may know, GPT-5.5 was officially launched on April 23, 2026. The latest model introduces major advancements in reasoning, agentic coding, deep research, and autonomous computer use. Here are some of its standout features: [...] ChatGPT Versions
#
# Release Date
#
# Salient Features
#
# ChatGPT 5.6
#
# June 2026
#
# GPT-5.6 prioritizes dvanced reasoning, robust cybersecurity, and long-horizon agentic workflows. It has three tiers: Sol (flagship), Terra (balanced), and Luna (fastest).
#
# ChatGPT 5.4
#
# March 2026
#
# It focuses on reasoning, agentic workflows, and coding. It supports deep web search and helps maintain context better for queries that need longer thinking.
#
# ChatGPT 5.3
#
# GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was launched in March 2026.
#
# It improves collaboration and supports full-cycle software development. It offers more accurate answers.
#
# ChatGPT 5.2
#
# December 2025
#
# GPT-5.2 supports routine tasks and learning. Users were allowed to ask technical queries in a more conversational tone. [...] | Scheduled Tasks in ChatGPT | January 2025 | Schedule Tasks were automated. Users could easily set up notifications, daily reports, and AI-generated messages. |
# | OpenAI o3 Preview | December 2024 | This model announced improvements in self-correction, reliability, and problem-solving. |
# | Full o1 Model Launch | December 2024 | This model was more impactful than the previous o1-preview model. Users experienced features like function calling, image analysis, and the “Reasoning Effort” parameter. |
# | Sora Launch | December 2024 | This update or release launched the “Text-to-Video Generation” feature. It helped create top-notch 20-second videos in 1080p resolution. |
